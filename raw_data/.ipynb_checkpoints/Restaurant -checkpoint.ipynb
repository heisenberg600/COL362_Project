# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="geoapiExercises")

# %%
restaurant=pd.read_csv('Datafiniti_Fast_Food_Restaurants.csv')
restaurant_bt=pd.read_csv('just tacos and burritos.csv')

# %%
restaurant.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           10000 non-null  object
#  1   dateAdded    10000 non-null  object
#  2   dateUpdated  10000 non-null  object
#  3   address      10000 non-null  object
#  4   categories   10000 non-null  object
#  5   city         10000 non-null  object
#  6   country      10000 non-null  object
#  7   keys         10000 non-null  object
#  8   latitude     10000 non-null  float64
#  9   longitude    10000 non-null  float64
#  10  name         10000 non-null  object
#  11  postalCode   10000 non-null  object
#  12  province     10000 non-null  object
#  13  sourceURLs   10000 non-null  object
#  14  websites     10000 non-null  object
# dtypes: float64(2), object(13)
# memory usage: 1.1+ MB

# %%
restaurant_bt.dropna(how='all',axis=1,inplace=True)
restaurant_bt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77260 entries, 0 to 77259
# Data columns (total 26 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  77260 non-null  object
#  1   address             77260 non-null  object
#  2   categories          77260 non-null  object
#  3   city                77260 non-null  object
#  4   country             77260 non-null  object
#  5   cuisines            38384 non-null  object
#  6   dateAdded           77260 non-null  object
#  7   dateUpdated         77260 non-null  object
#  8   keys                77260 non-null  object
#  9   latitude            55636 non-null  float64
#  10  longitude           55636 non-null  float64
#  11  menuPageURL         10054 non-null  object
#  12  menus.amountMax     40260 non-null  float64
#  13  menus.amountMin     40260 non-null  float64
#  14  menus.category      3729 non-null   object
# ...

# %%
restaurant_bt
# Out:
#                          id                   address  \
# 0      AVwc__cikufWRAb51QjV         610 Commercial St
# 1      AVwc__cikufWRAb51QjV         610 Commercial St
# 2      AVwc__dF_7pvs4fz1Ncy      9521 Morton Davis Dr
# 3      AVwc__kCByjofQCxkdm-  10550 W I 25 Frontage Rd
# 4      AVwc__WtByjofQCxkdkR             8495 W 3rd St
# ...                     ...                       ...
# 77255  AVzRLlQNLD2H7whiWdH_             3919 24th St.
# 77256  AVzRLlQNLD2H7whiWdH_             3919 24th St.
# 77257  AVzRLlQNLD2H7whiWdH_             3919 24th St.
# 77258  AVzRLlQNLD2H7whiWdH_             3919 24th St.
# 77259  AVzRLlQNLD2H7whiWdH_             3919 24th St.
#
#                                               categories           city  \
# 0      Restaurant Delivery Service,Restaurants,Pizza,...       Atchison
# 1      Restaurant Delivery Service,Restaurants,Pizza,...       Atchison
# 2           Golf Course, American Restaurant, and Resort      Patterson
# ...

# %%
print(restaurant_bt['province'].value_counts())
# Out:
# CA                 23664
# TX                  6099
# FL                  2977
# IL                  2725
# AZ                  2355
#                    ...
# Stadium                1
# Scituate Harbor        1
# Woodcrest              1
# Norland Park           1
# Williston Pk           1
# Name: province, Length: 1097, dtype: int64

# %%
restaurant_bt=restaurant_bt.dropna(subset=['latitude', 'longitude'],how='all')

# %%
restaurant_bt=restaurant_bt.drop_duplicates(subset=['id', 'address'], keep='first')
restaurant_bt.dropna(how='any',subset=['name'],axis=0,inplace=True)
restaurant_bt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14757 entries, 0 to 77250
# Data columns (total 26 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  14757 non-null  object
#  1   address             14757 non-null  object
#  2   categories          14757 non-null  object
#  3   city                14757 non-null  object
#  4   country             14757 non-null  object
#  5   cuisines            9719 non-null   object
#  6   dateAdded           14757 non-null  object
#  7   dateUpdated         14757 non-null  object
#  8   keys                14757 non-null  object
#  9   latitude            14757 non-null  float64
#  10  longitude           14757 non-null  float64
#  11  menuPageURL         2602 non-null   object
#  12  menus.amountMax     7548 non-null   float64
#  13  menus.amountMin     7548 non-null   float64
#  14  menus.category      1198 non-null   object
# ...

# %%
convert={'Alabama':'AL','Nebraska':'NE','Alaska':'AK','Nevada':'NV','Arizona':'AZ','New Hampshire':'NH','Arkansas':'AR','New Jersey':'NJ','California':'CA','New Mexico':'NM','Colorado':'CO','New York':'NY','Connecticut':'CT','North Carolina':'NC','Delaware':'DE','North Dakota':'ND','District of Columbia':'DC','Ohio':'OH','Florida':'FL','Oklahoma':'OK','Georgia':'GA','Oregon':'OR','Hawaii':'HI','Pennsylvania':'PA','Idaho':'ID','Puerto Rico':'PR','Illinois':'IL','Rhode Island':'RI','Indiana':'IN','South Carolina':'SC','Iowa':'IA','South Dakota':'SD','Kansas':'KS','Tennessee':'TN','Kentucky':'KY','Texas':'TX','Louisiana':'LA','Utah':'UT','Maine':'ME','Vermont':'VT','Maryland':'MD','Virginia':'VA','Massachusetts':'MA','Virgin Islands':'VI','Michigan':'MI','Washington':'WA','Minnesota':'MN','West Virginia':'WV','Mississippi':'MS','Wisconsin':'WI','Missouri':'MO','Wyoming':'WY','Montana':'MT'}

# %%
# province=[]
# for i in tqdm(range(len(restaurant_bt))):
#     lat=restaurant_bt.iloc[i]['latitude']
#     long=restaurant_bt.iloc[i]['longitude']
#     try:
#         results=geolocator.reverse(str(lat)+', '+str(long))
#         state=convert[results.raw['address']['state']]
#     except:
#         state=''
#     province.append(state)
# df.drop('province',inplace=True,axis=1)
# df['province']=province

# %%
restautrant_bt_new=restaurant_bt[['id','name','dateAdded','priceRangeMin','priceRangeMax','menus.name','websites','latitude','longitude','address','city','province','postalCode']]

# %%
restautrant_bt_new['taco_burrito']=[1 for i in range(len(restautrant_bt_new))]
# Out:
# <ipython-input-97-c87a7aa7ec37>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   restautrant_bt_new['taco_burrito']=[1 for i in range(len(restautrant_bt_new))]

# %%
restautrant_bt_new
# Out:
#                          id                                     name  \
# 0      AVwc__cikufWRAb51QjV                          Gambino's Pizza
# 2      AVwc__dF_7pvs4fz1Ncy        Diablo Grande Golf & Country Club
# 4      AVwc__WtByjofQCxkdkR                 Baja Fresh Mexican Grill
# 15     AVwc_1y6kufWRAb51O6w                               Java Joe's
# 18     AVwc_2OQ_7pvs4fz1L5H  Mago Grill & Cantina - South Barrington
# ...                     ...                                      ...
# 77235  AVzRLk2GFcQ3k02bBtCV                              El Farolito
# 77238  AVzRLkwULD2H7whiWdHX                          Donna's Tamales
# 77245  AVzRLkyc-gnIPe8DS05C                        Chevy's Fresh Mex
# 77249  AVzRLlOl3D1zeR_xBVwZ                              El Cafetazo
# 77250  AVzRLlQNLD2H7whiWdH_                       La Casona Taqueria
#
#                   dateAdded  priceRangeMin  priceRangeMax  \
# 0      2016-03-02T11:49:34Z            NaN            NaN
# ...

# %%
restaurant.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           10000 non-null  object
#  1   dateAdded    10000 non-null  object
#  2   dateUpdated  10000 non-null  object
#  3   address      10000 non-null  object
#  4   categories   10000 non-null  object
#  5   city         10000 non-null  object
#  6   country      10000 non-null  object
#  7   keys         10000 non-null  object
#  8   latitude     10000 non-null  float64
#  9   longitude    10000 non-null  float64
#  10  name         10000 non-null  object
#  11  postalCode   10000 non-null  object
#  12  province     10000 non-null  object
#  13  sourceURLs   10000 non-null  object
#  14  websites     10000 non-null  object
# dtypes: float64(2), object(13)
# memory usage: 1.1+ MB

# %%
restaurant_new=restaurant[['id','name','dateAdded','address','city','latitude','longitude','postalCode','province','websites']]

# %%
restaurant_new
# Out:
#                         id            name             dateAdded  \
# 0     AVwcmSyZIN2L1WUfmxyw  SONIC Drive In  2015-10-19T23:47:58Z
# 1     AVwcmSyZIN2L1WUfmxyw  SONIC Drive In  2015-10-19T23:47:58Z
# 2     AVwcopQoByjofQCxgfVa       Taco Bell  2016-03-29T05:06:36Z
# 3     AVweXN5RByjofQCxxilK          Arby's  2017-01-03T07:46:11Z
# 4     AWQ6MUvo3-Khe5l_j3SG  Steak 'n Shake  2018-06-26T02:59:43Z
# ...                    ...             ...                   ...
# 9995  AV12gJwna4HuVbed9Ayg       Pizza Hut  2017-07-24T21:28:46Z
# 9996  AV12gJxKIxWefVJwhpzS       Pizza Hut  2017-07-24T21:28:46Z
# 9997  AVwdJMdSByjofQCxl8Vr       Pizza Hut  2015-10-24T00:17:32Z
# 9998  AVwdl2cykufWRAb57ZPs       Pizza Hut  2016-04-05T02:59:45Z
# 9999  AVwdecWKIN2L1WUfwMWU       Pizza Hut  2016-11-08T02:26:32Z
#
#                    address           city   latitude  longitude postalCode  \
# 0         800 N Canal Blvd      Thibodaux  29.814697 -90.814742      70301
# ...

# %%
restaurant_new['priceRangeMin']=np.nan
restaurant_new['priceRangeMax']=np.nan
restaurant_new['menuDesc']=np.nan
restaurant_new['flag']=[0 for i in range(len(restaurant_new))]
# Out:
# <ipython-input-102-02175d3c80c0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   restaurant_new['priceRangeMin']=np.nan
# <ipython-input-102-02175d3c80c0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   restaurant_new['priceRangeMax']=np.nan
# <ipython-input-102-02175d3c80c0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
restaurant_new
# Out:
#                         id            name             dateAdded  \
# 0     AVwcmSyZIN2L1WUfmxyw  SONIC Drive In  2015-10-19T23:47:58Z
# 1     AVwcmSyZIN2L1WUfmxyw  SONIC Drive In  2015-10-19T23:47:58Z
# 2     AVwcopQoByjofQCxgfVa       Taco Bell  2016-03-29T05:06:36Z
# 3     AVweXN5RByjofQCxxilK          Arby's  2017-01-03T07:46:11Z
# 4     AWQ6MUvo3-Khe5l_j3SG  Steak 'n Shake  2018-06-26T02:59:43Z
# ...                    ...             ...                   ...
# 9995  AV12gJwna4HuVbed9Ayg       Pizza Hut  2017-07-24T21:28:46Z
# 9996  AV12gJxKIxWefVJwhpzS       Pizza Hut  2017-07-24T21:28:46Z
# 9997  AVwdJMdSByjofQCxl8Vr       Pizza Hut  2015-10-24T00:17:32Z
# 9998  AVwdl2cykufWRAb57ZPs       Pizza Hut  2016-04-05T02:59:45Z
# 9999  AVwdecWKIN2L1WUfwMWU       Pizza Hut  2016-11-08T02:26:32Z
#
#                    address           city   latitude  longitude postalCode  \
# 0         800 N Canal Blvd      Thibodaux  29.814697 -90.814742      70301
# ...

# %%
restaurant_new=restaurant_new.rename(columns = {'flag':'taco_burrito'})
restaurant_new
# Out:
#                         id            name             dateAdded  \
# 0     AVwcmSyZIN2L1WUfmxyw  SONIC Drive In  2015-10-19T23:47:58Z
# 1     AVwcmSyZIN2L1WUfmxyw  SONIC Drive In  2015-10-19T23:47:58Z
# 2     AVwcopQoByjofQCxgfVa       Taco Bell  2016-03-29T05:06:36Z
# 3     AVweXN5RByjofQCxxilK          Arby's  2017-01-03T07:46:11Z
# 4     AWQ6MUvo3-Khe5l_j3SG  Steak 'n Shake  2018-06-26T02:59:43Z
# ...                    ...             ...                   ...
# 9995  AV12gJwna4HuVbed9Ayg       Pizza Hut  2017-07-24T21:28:46Z
# 9996  AV12gJxKIxWefVJwhpzS       Pizza Hut  2017-07-24T21:28:46Z
# 9997  AVwdJMdSByjofQCxl8Vr       Pizza Hut  2015-10-24T00:17:32Z
# 9998  AVwdl2cykufWRAb57ZPs       Pizza Hut  2016-04-05T02:59:45Z
# 9999  AVwdecWKIN2L1WUfwMWU       Pizza Hut  2016-11-08T02:26:32Z
#
#                    address           city   latitude  longitude postalCode  \
# 0         800 N Canal Blvd      Thibodaux  29.814697 -90.814742      70301
# ...

# %%
restautrant_bt_new=restautrant_bt_new.rename(columns = {'menus.name':'menuDesc'})

# %%
restaurant_new=restaurant_new[restautrant_bt_new.columns]
restaurant_new
# Out:
#                         id            name             dateAdded  \
# 0     AVwcmSyZIN2L1WUfmxyw  SONIC Drive In  2015-10-19T23:47:58Z
# 1     AVwcmSyZIN2L1WUfmxyw  SONIC Drive In  2015-10-19T23:47:58Z
# 2     AVwcopQoByjofQCxgfVa       Taco Bell  2016-03-29T05:06:36Z
# 3     AVweXN5RByjofQCxxilK          Arby's  2017-01-03T07:46:11Z
# 4     AWQ6MUvo3-Khe5l_j3SG  Steak 'n Shake  2018-06-26T02:59:43Z
# ...                    ...             ...                   ...
# 9995  AV12gJwna4HuVbed9Ayg       Pizza Hut  2017-07-24T21:28:46Z
# 9996  AV12gJxKIxWefVJwhpzS       Pizza Hut  2017-07-24T21:28:46Z
# 9997  AVwdJMdSByjofQCxl8Vr       Pizza Hut  2015-10-24T00:17:32Z
# 9998  AVwdl2cykufWRAb57ZPs       Pizza Hut  2016-04-05T02:59:45Z
# 9999  AVwdecWKIN2L1WUfwMWU       Pizza Hut  2016-11-08T02:26:32Z
#
#       priceRangeMin  priceRangeMax  menuDesc  \
# 0               NaN            NaN       NaN
# 1               NaN            NaN       NaN
# 2               NaN            NaN       NaN
# ...

# %%
frames=[restaurant_new,restautrant_bt_new]
bigTable=pd.concat(frames)

# %%
bigTable
# Out:
#                          id                name             dateAdded  \
# 0      AVwcmSyZIN2L1WUfmxyw      SONIC Drive In  2015-10-19T23:47:58Z
# 1      AVwcmSyZIN2L1WUfmxyw      SONIC Drive In  2015-10-19T23:47:58Z
# 2      AVwcopQoByjofQCxgfVa           Taco Bell  2016-03-29T05:06:36Z
# 3      AVweXN5RByjofQCxxilK              Arby's  2017-01-03T07:46:11Z
# 4      AWQ6MUvo3-Khe5l_j3SG      Steak 'n Shake  2018-06-26T02:59:43Z
# ...                     ...                 ...                   ...
# 77235  AVzRLk2GFcQ3k02bBtCV         El Farolito  2017-06-22T19:01:31Z
# 77238  AVzRLkwULD2H7whiWdHX     Donna's Tamales  2017-06-22T19:01:31Z
# 77245  AVzRLkyc-gnIPe8DS05C   Chevy's Fresh Mex  2017-06-22T19:01:31Z
# 77249  AVzRLlOl3D1zeR_xBVwZ         El Cafetazo  2017-06-22T19:01:33Z
# 77250  AVzRLlQNLD2H7whiWdH_  La Casona Taqueria  2017-06-22T19:01:33Z
#
#        priceRangeMin  priceRangeMax           menuDesc  \
# 0                NaN            NaN                NaN
# ...

# %%
bigTable=bigTable.drop_duplicates(subset=['id', 'address'], keep='first')

# %%
val=[np.nan if np.isnan(bigTable.iloc[i]['priceRangeMin']) else (bigTable.iloc[i]['priceRangeMin']+bigTable.iloc[i]['priceRangeMax'])/2 for i in range(len(bigTable))]

# %%
bigTable['priceRangeAvg']=val
# Out:
# <ipython-input-111-e18ebe9e8848>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bigTable['priceRangeAvg']=val

# %%
bigTable=bigTable.drop_duplicates(subset=['id'], keep='first')
bigTable.set_index('id',inplace=True)

# %%
indexa = bigTable[bigTable.priceRangeAvg.isna()].index
value = np.random.normal(loc=bigTable.priceRangeAvg.mean(), scale=bigTable.priceRangeAvg.std(), size=bigTable.priceRangeAvg.isna().sum())
value=np.array(list(map(lambda x: abs(x)+2, value)))
bigTable.priceRangeAvg.fillna(pd.Series(value, index=indexa), inplace=True)

# %%
bigTable
# Out:
#                                     name             dateAdded  priceRangeMin  \
# id
# AVwcmSyZIN2L1WUfmxyw      SONIC Drive In  2015-10-19T23:47:58Z            NaN
# AVwcopQoByjofQCxgfVa           Taco Bell  2016-03-29T05:06:36Z            NaN
# AVweXN5RByjofQCxxilK              Arby's  2017-01-03T07:46:11Z            NaN
# AWQ6MUvo3-Khe5l_j3SG      Steak 'n Shake  2018-06-26T02:59:43Z            NaN
# AVwc57jLkufWRAb50ROs             Wendy's  2015-10-23T23:59:49Z            NaN
# ...                                  ...                   ...            ...
# AVzRLk2GFcQ3k02bBtCV         El Farolito  2017-06-22T19:01:31Z            NaN
# AVzRLkwULD2H7whiWdHX     Donna's Tamales  2017-06-22T19:01:31Z            NaN
# AVzRLkyc-gnIPe8DS05C   Chevy's Fresh Mex  2017-06-22T19:01:31Z            NaN
# AVzRLlOl3D1zeR_xBVwZ         El Cafetazo  2017-06-22T19:01:33Z            NaN
# AVzRLlQNLD2H7whiWdH_  La Casona Taqueria  2017-06-22T19:01:33Z            NaN
#
# ...

# %%
bigTable['priceRangeAvg']=bigTable['priceRangeAvg'].apply(lambda x:round(x))

# %%
bigTable['avgReview']=np.nan

# %%
bigTable=bigTable[bigTable['province'].isin(convert.values())]

# %%
cityProv=bigTable[['city','province']]

# %%
cityProv
# Out:
#                               city province
# id
# AVwcmSyZIN2L1WUfmxyw     Thibodaux       LA
# AVwcopQoByjofQCxgfVa  Pigeon Forge       TN
# AVweXN5RByjofQCxxilK  Pigeon Forge       TN
# AWQ6MUvo3-Khe5l_j3SG        Morrow       GA
# AVwc57jLkufWRAb50ROs       Detroit       MI
# ...                            ...      ...
# AVz0WYK2-gnIPe8DUW4J        Dallas       TX
# AVz0WZ18FcQ3k02bDO8m   Weatherford       TX
# AVz0WZf3-gnIPe8DUW4y     Mansfield       TX
# AVz0WZjfFcQ3k02bDO8a    Little Elm       TX
# AVz0WZsS-gnIPe8DUW45        Irving       TX
#
# [21749 rows x 2 columns]

# %%
bigTable['cityId']=np.nan
cityProv['cityId']=np.nan
dict_helper={}
index=0
l=bigTable.index.to_list()
for i in l:
    try:
        bigTable.at[i,'cityId']=dict_helper[cityProv.at[i,'city']+cityProv.at[i,'province']]
        cityProv.at[i,'cityId']=dict_helper[cityProv.at[i,'city']+cityProv.at[i,'province']]
    except:
        index+=1
        dict_helper[cityProv.at[i,'city']+cityProv.at[i,'province']]=index
        bigTable.at[i,'cityId']=index
        cityProv.at[i,'cityId']=index
# Out:
# <ipython-input-127-17efe48cc41f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bigTable['cityId']=np.nan
# <ipython-input-127-17efe48cc41f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cityProv['cityId']=np.nan

# %%
cityProv['cityId']=cityProv['cityId'].apply(lambda x: int(x))
bigTable['cityId']=bigTable['cityId'].apply(lambda x: int(x))
# Out:
# <ipython-input-128-f6c06de10505>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cityProv['cityId']=cityProv['cityId'].apply(lambda x: int(x))
# <ipython-input-128-f6c06de10505>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bigTable['cityId']=bigTable['cityId'].apply(lambda x: int(x))

# %%
cityProv
# Out:
#                               city province  cityId
# id
# AVwcmSyZIN2L1WUfmxyw     Thibodaux       LA       1
# AVwcopQoByjofQCxgfVa  Pigeon Forge       TN       2
# AVweXN5RByjofQCxxilK  Pigeon Forge       TN       2
# AWQ6MUvo3-Khe5l_j3SG        Morrow       GA       3
# AVwc57jLkufWRAb50ROs       Detroit       MI       4
# ...                            ...      ...     ...
# AVz0WYK2-gnIPe8DUW4J        Dallas       TX     806
# AVz0WZ18FcQ3k02bDO8m   Weatherford       TX     856
# AVz0WZf3-gnIPe8DUW4y     Mansfield       TX    2873
# AVz0WZjfFcQ3k02bDO8a    Little Elm       TX     356
# AVz0WZsS-gnIPe8DUW45        Irving       TX    1955
#
# [21749 rows x 3 columns]

# %%
cityProv.drop_duplicates(subset=['cityId'], keep='first',inplace=True)
# Out:
# <ipython-input-130-61bd3dcb2aaf>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cityProv.drop_duplicates(subset=['cityId'], keep='first',inplace=True)

# %%
cityProv.set_index('cityId',inplace=True)

# %%
cityProv
# Out:
#                   city province
# cityId
# 1            Thibodaux       LA
# 2         Pigeon Forge       TN
# 3               Morrow       GA
# 4              Detroit       MI
# 5            Oceanside       CA
# ...                ...      ...
# 4938          Eldridge       IA
# 4939         Dadeville       AL
# 4940            Oxford       NC
# 4941        Burlington       KS
# 4942    San Tan Valley       AZ
#
# [4942 rows x 2 columns]

# %%
province=pd.DataFrame(list(convert.items()),columns = ['name','provinceId']) 
province.set_index('provinceId',inplace=True)

# %%
province
# Out:
#                             name
# provinceId
# AL                       Alabama
# NE                      Nebraska
# AK                        Alaska
# NV                        Nevada
# AZ                       Arizona
# NH                 New Hampshire
# AR                      Arkansas
# NJ                    New Jersey
# CA                    California
# NM                    New Mexico
# CO                      Colorado
# NY                      New York
# CT                   Connecticut
# NC                North Carolina
# DE                      Delaware
# ND                  North Dakota
# DC          District of Columbia
# OH                          Ohio
# FL                       Florida
# OK                      Oklahoma
# GA                       Georgia
# OR                        Oregon
# HI                        Hawaii
# PA                  Pennsylvania
# ID                         Idaho
# PR                   Puerto Rico
# IL                      Illinois
# ...

# %%
bigTable
# Out:
#                                                     name  \
# id
# AVwcmSyZIN2L1WUfmxyw                      SONIC Drive In
# AVwcopQoByjofQCxgfVa                           Taco Bell
# AVweXN5RByjofQCxxilK                              Arby's
# AWQ6MUvo3-Khe5l_j3SG                      Steak 'n Shake
# AVwc57jLkufWRAb50ROs                             Wendy's
# ...                                                  ...
# AVz0WYK2-gnIPe8DUW4J   Chino Chinatown at Trinity Groves
# AVz0WZ18FcQ3k02bDO8m                 Los Vaqueros - West
# AVz0WZf3-gnIPe8DUW4y  El Primo's Mexican Grill & Cantina
# AVz0WZjfFcQ3k02bDO8a                            Hula Hut
# AVz0WZsS-gnIPe8DUW45          LAW at Four Seasons Dallas
#
#                                  dateAdded  priceRangeMin  priceRangeMax  \
# id
# AVwcmSyZIN2L1WUfmxyw  2015-10-19T23:47:58Z            NaN            NaN
# AVwcopQoByjofQCxgfVa  2016-03-29T05:06:36Z            NaN            NaN
# ...

# %%
restId=[i for i in range(1,len(bigTable)+1)]
bigTable['restId']=restId
bigTable.set_index('restId',inplace=True)
# Out:
# <ipython-input-136-c0fe396a9d66>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bigTable['restId']=restId

# %%
bigTable
# Out:
#                                       name             dateAdded  \
# restId
# 1                           SONIC Drive In  2015-10-19T23:47:58Z
# 2                                Taco Bell  2016-03-29T05:06:36Z
# 3                                   Arby's  2017-01-03T07:46:11Z
# 4                           Steak 'n Shake  2018-06-26T02:59:43Z
# 5                                  Wendy's  2015-10-23T23:59:49Z
# ...                                    ...                   ...
# 21745    Chino Chinatown at Trinity Groves  2017-06-29T14:55:25Z
# 21746                  Los Vaqueros - West  2017-06-29T14:55:32Z
# 21747   El Primo's Mexican Grill & Cantina  2017-06-29T14:55:31Z
# 21748                             Hula Hut  2017-06-29T14:55:31Z
# 21749           LAW at Four Seasons Dallas  2017-06-29T14:55:32Z
#
#         priceRangeMin  priceRangeMax                menuDesc  \
# restId
# 1                 NaN            NaN                     NaN
# ...

# %%
bigTable['dateAdded']=bigTable['dateAdded'].apply(lambda x: x[:10])
# Out:
# <ipython-input-138-3208dcdd3d7c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bigTable['dateAdded']=bigTable['dateAdded'].apply(lambda x: x[:10])

# %%
bigTable_n=bigTable[['name','dateAdded','menuDesc','websites','latitude','longitude','cityId','address','postalCode','taco_burrito','priceRangeAvg','avgReview']]

# %%
bigTable_n
# Out:
#                                       name   dateAdded  \
# restId
# 1                           SONIC Drive In  2015-10-19
# 2                                Taco Bell  2016-03-29
# 3                                   Arby's  2017-01-03
# 4                           Steak 'n Shake  2018-06-26
# 5                                  Wendy's  2015-10-23
# ...                                    ...         ...
# 21745    Chino Chinatown at Trinity Groves  2017-06-29
# 21746                  Los Vaqueros - West  2017-06-29
# 21747   El Primo's Mexican Grill & Cantina  2017-06-29
# 21748                             Hula Hut  2017-06-29
# 21749           LAW at Four Seasons Dallas  2017-06-29
#
#                       menuDesc  \
# restId
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# 5                          NaN
# ...                        ...
# 21745          Dover Sole Taco
# ...

# %%
def random_phone_num_generator():
    first = str(random.randint(100, 999))
    second = str(random.randint(1, 888)).zfill(3)
    last = (str(random.randint(1, 9998)).zfill(4))
    while last in ['1111', '2222', '3333', '4444', '5555', '6666', '7777', '8888']:
        last = (str(random.randint(1, 9998)).zfill(4))
    return '({})-{}-{}'.format(first, second, last)
phone=[random_phone_num_generator() for i in range(len(bigTable_n))]
bigTable_n['phoneNo']=phone
# Out:
# <ipython-input-151-e0ea5d81ec97>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bigTable_n['phoneNo']=phone

# %%
bigTable_n
# Out:
#                                       name   dateAdded  \
# restId
# 1                           SONIC Drive In  2015-10-19
# 2                                Taco Bell  2016-03-29
# 3                                   Arby's  2017-01-03
# 4                           Steak 'n Shake  2018-06-26
# 5                                  Wendy's  2015-10-23
# ...                                    ...         ...
# 21745    Chino Chinatown at Trinity Groves  2017-06-29
# 21746                  Los Vaqueros - West  2017-06-29
# 21747   El Primo's Mexican Grill & Cantina  2017-06-29
# 21748                             Hula Hut  2017-06-29
# 21749           LAW at Four Seasons Dallas  2017-06-29
#
#                       menuDesc  \
# restId
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# 5                          NaN
# ...                        ...
# 21745          Dover Sole Taco
# ...
